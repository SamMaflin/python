# %%
import pandas as pd
# set display options
pd.set_option("display.max_columns", 99999)
pd.set_option("display.width", 99999)
pd.set_option("display.max_colwidth", 99999)
# insert league and season
league = "ENG-League Two"
season = "2122" 
# don't touch below
event_dir = f"soccerdatawhoscored/data/raw/{league}_{season}"

# %%
from whoscored_scraper import fetch_whoscored_raw_to_csv
# league, season, event_dir
fetch_whoscored_raw_to_csv(league, season, event_dir)
# Out:
# [11/24/25 12:33:22] INFO     No custom team name replacements found. You can configure these in       ]8;id=945592;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=87090;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\SMafl\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=20616;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=679111;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_config.py#197\197]8;;\
#                              C:\Users\SMafl\soccerdata\config\league_dict.json.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from whoscored_scraper import fetch_whoscored_raw_to_csv
#       2 # league, season, event_dir
# ----> 3 fetch_whoscored_raw_to_csv(league, season, event_dir)
#
# File c:\Users\SMafl\python\whoscored\whoscored_scraper.py:31, in fetch_whoscored_raw_to_csv(league, season, event_dir, data_dir)
#      28 event_dir.mkdir(parents=True, exist_ok=True)
#      30 # Initialize WhoScored object
# ---> 31 ws = WhoScored(leagues=[league], seasons=[season], data_dir=data_dir)
#      33 # Read schedule
#      34 df_schedule = ws.read_schedule()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\whoscored.py:169, in WhoScored.__init__(self, leagues, seasons, proxy, no_cache, no_store, data_dir, path_to_browser, headless)
#     155 def __init__(
#     156     self,
#     157     leagues: Optional[Union[str, list[str]]] = None,
#    (...)    166     headless: bool = False,
#     167 ):
#     168     """Initialize the WhoScored reader."""
# --> 169     super().__init__(
#     170         leagues=leagues,
#     171         proxy=proxy,
#     172         no_cache=no_cache,
#     173         no_store=no_store,
#     174         data_dir=data_dir,
#     175         path_to_browser=path_to_browser,
#     176         headless=headless,
#     177     )
#     178     self.seasons = seasons  # type: ignore
#     179     self.rate_limit = 5
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_common.py:572, in BaseSeleniumReader.__init__(self, leagues, proxy, no_cache, no_store, data_dir, path_to_browser, headless)
#     559 def __init__(
#     560     self,
#     561     leagues: Optional[Union[str, list[str]]] = None,
#    (...)    569     headless: bool = True,
#     570 ):
#     571     """Initialize the reader."""
# --> 572     super().__init__(
#     573         no_cache=no_cache,
#     574         no_store=no_store,
#     575         leagues=leagues,
#     576         proxy=proxy,
#     577         data_dir=data_dir,
#     578     )
#     579     self.path_to_browser = path_to_browser
#     580     self.headless = headless
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_common.py:254, in BaseReader.__init__(self, leagues, proxy, no_cache, no_store, data_dir)
#     251 else:
#     252     self.proxy = dict
# --> 254 self._selected_leagues = leagues  # type: ignore
#     255 self.no_cache = no_cache
#     256 self.no_store = no_store
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_common.py:421, in BaseReader._selected_leagues(self, ids)
#     419 for i in ids:
#     420     if i not in self._all_leagues():
# --> 421         raise ValueError(
#     422             f"""
#     423             Invalid league '{i}'. Valid leagues are:
#     424             {pprint.pformat(self.available_leagues())}
#     425             """
#     426         )
#     427     tmp_league_dict[i] = self._all_leagues()[i]
#     428 self._leagues_dict = tmp_league_dict
#
# ValueError:
#                         Invalid league 'ENG-League Two'. Valid leagues are:
#                         ['ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']
