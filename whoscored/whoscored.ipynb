# %%
import pandas as pd
# set display options
pd.set_option("display.max_columns", 99999)
pd.set_option("display.width", 99999)
pd.set_option("display.max_colwidth", 99999)
# insert league and season
league = "ENG-Premier League"
season = "2526" 
# don't touch below
event_dir = f"soccerdatawhoscored/data/raw/{league}_{season}"

# %%
from whoscored.whoscored_scraper import fetch_whoscored_raw_to_csv
# league, season, event_dir
fetch_whoscored_raw_to_csv(league, season, event_dir)
# Out:
# [10/01/25 20:47:31] INFO     Saving cached data to whoscored\data\whoscored                          ]8;id=188015;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=349272;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\_common.py#263\263]8;;\
# [10/01/25 20:48:17] INFO     Retrieving calendar for ENG-Premier League 2526                       ]8;id=100095;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\whoscored.py\whoscored.py]8;;\:]8;id=964568;file://C:\Users\SMafl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\soccerdata\whoscored.py#374\374]8;;\
# ...
